# %% [markdown]
# #MultiClass Classification

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
df=pd.read_csv("/content/iris.csv")

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# sepal length (cm)
#
# ده طول الـ sepal (السبلات) بالسنتيمتر.
#
# الـ sepal هو الجزء الأخضر اللي بيكون حوالين الزهرة وهي لسه bud.
# بيدينا فكرة عن حجم الزهرة من برّه.
#
#
# 2. sepal width (cm)
#
# ده عرض الـ sepal.
#
# بيقيس مدى اتساع الجزء الخارجي من الزهرة.
#
#
#
# petal length (cm)
#
# ده طول الـ petal (بتلات الزهرة).
#
# الـ petal هو الجزء الداخلي الملون من الزهرة.
# ده أهم feature تقريبًا في التمييز بين الأنواع.
#
#
#
#
# petal width (cm)
#
# ده عرض الـ petal.
#
# بيكمل معلومات شكل البتلة.
#
#
#
# ![image.png](data:image/png;base64,...)

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
x=df.drop("target",axis=1)
y=df["target"]

# %%
x
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int64

# %%
print(y.value_counts())
# Out:
# target
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    x, y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# %%
#
y_test.shape
# Out:
# (30,)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = LogisticRegression(
    multi_class='multinomial',
    max_iter=1000
)

model.fit(X_train_scaled, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(max_iter=1000, multi_class='multinomial')

# %%
y_pred = model.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([0, 2, 1, 1, 0, 1, 0, 0, 2, 1, 2, 2, 2, 1, 0, 0, 0, 1, 1, 2, 0, 2,
#        1, 1, 2, 2, 1, 0, 2, 0])

# %%
y_prob = model.predict_proba(X_test_scaled)

print(y_prob[:2])
# Out:
# [[9.78818005e-01 2.11816311e-02 3.63821812e-07]
#  [3.79836951e-03 3.69220168e-01 6.26981463e-01]]

# %%
np.argmax([9.78818005e-01 ,2.11816311e-02 ,3.63821812e-07])
# Out:
# np.int64(0)

# %%
np.argmax([[3.79836951e-03, 3.69220168e-01, 6.26981463e-01]])
# Out:
# np.int64(2)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9333333333333333
