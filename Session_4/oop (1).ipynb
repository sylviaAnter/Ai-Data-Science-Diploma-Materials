# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 1

# %% [markdown]
# #*OOP* = object oriented programming

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####we have alot of data types ...
# ####so why not to divide these data types
# ####each grp in a container
# container for intergers numbers another one for list and so on ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
y=100
print(type(y))
# Out:
# <class 'int'>

# %%
name='maha'
print(type(name))
# Out:
# <class 'str'>

# %%
x=[1,2,3,4,5,6]
u=['uhuhu',100,10.25]
print(type(x))
# Out:
# <class 'list'>

# %%
help(x)
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, index, /)
#  |      Return self[index].
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def hello():
  print("Hello MAHA")

# %%
hello()
# Out:
# Hello MAHA

# %%
print(type(hello))
# Out:
# <class 'function'>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #How To create Class :

# %%
class person:
  #Attributes
  name='Ahmed'
  age=25
  gender='male'
  occupation='Ai Engineer'
  #Methods()
  def walk():
    print("Ahmed is walking")
  def talk():
    print("Ahmed is talking")
  def eat():
    print("ahmed is eating")
  def work():
    print("Ahmed is busy now")

# %% [markdown]
# #how we can use the class

# %%
#define list

# %%
x=person()
print(x.name)
print(x.age)
print(x.gender)
print(x.occupation)
# Out:
# Ahmed
# 25
# male
# Ai Engineer

# %%
x.walk()
x.talk()
x.eat()
x.work()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_643/2471240715.py in <cell line: 0>()
# ----> 1 x.walk()
#       2 x.talk()
#       3 x.eat()
#       4 x.work()
#
# TypeError: person.walk() takes 0 positional arguments but 1 was given

# %%
#help

# %% [markdown]
# #Self = x
# ###self = current object

# %%
class person:
  #Attributes
  name='Ahmed'
  age=25
  gender='male'
  occupation='Ai Engineer'
  #Methods()
  def walk(x):
    print("Ahmed is walking")
  def talk(x):
    print("Ahmed is talking")
  def eat(x):
    print("ahmed is eating")
  def work(x):
    print("Ahmed is busy now")

# %%
x=person()
print(x.name)
print(x.age)
print(x.gender)
print(x.occupation)
# Out:
# Ahmed
# 25
# male
# Ai Engineer

# %%
x.walk()
x.talk()
x.eat()
x.work()
# Out:
# Ahmed is walking
# Ahmed is talking
# ahmed is eating
# Ahmed is busy now

# %%
class person:
  #Attributes
  self.name
  age=25
  gender='male'
  occupation='Ai Engineer'
  #Methods()
  def walk(self):
    print("Ahmed is walking")
  def talk(self):
    print("Ahmed is talking")
  def eat(self):
    print("ahmed is eating")
  def work(self):
    print("Ahmed is busy now")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_643/2798158815.py in <cell line: 0>()
# ----> 1 class person:
#       2   #Attributes
#       3   self.name
#       4   age=25
#       5   gender='male'
#
# /tmp/ipykernel_643/2798158815.py in person()
#       1 class person:
#       2   #Attributes
# ----> 3   self.name
#       4   age=25
#       5   gender='male'
#
# NameError: name 'self' is not defined

# %% [markdown]
# #Constructor
# ####special function by defult run when we create any object
# #why using constructor ?
# ###to allow each object to have its information
# #how we can create constructor ?
#
#
# ```
# def __init__(self,name,age,...)
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class person:
  #constructor
  def __init__(self,name,age,gender,occupation):
    self.name=name
    self.age=age
    self.gender=gender
    self.occupation=occupation

  #Methods()
  def walk(self):
    print("Ahmed is walking")
  def talk(self):
    print("ahmed is talking")
  def eat(self):
    print("ahmed is eating")
  def work(self):
    print("ahmed is busy now")

# %%
y=person()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_643/3979969102.py in <cell line: 0>()
# ----> 1 y=person()
#
# TypeError: person.__init__() missing 4 required positional arguments: 'name', 'age', 'gender', and 'occupation'

# %%
p1=person('islam',30,'male','AI')

# %%
p1.name
# Out:
# 'islam'

# %%
p1.occupation
# Out:
# 'AI'

# %%
p1.age
# Out:
# 30

# %%
y=person('sylvia',25,'female','Ai_Engineer')

# %%
y.name
# Out:
# 'sylvia'

# %%
y.talk()
# Out:
# ahmed is talking

# %%
class person:
  #constructor
  def __init__(self,name,age,gender,occupation):
    self.name=name
    self.age=age
    self.gender=gender
    self.occupation=occupation

  #Methods()
  def walk(self):
    print(f"{self.name} is walking")

  #--------------------------------------------
  def talk(self):
    print(self.name ,"is talking")

  #--------------------------------------------
  def eat(self):
    print(f"{self.name} is eating")

  #---------------------------------------------
  def work(self):
    print(self.name," is busy now")

  #---------------------------------------------

# %%
y=person('sylvia',25,'female','Ai_Engineer')

# %%
y.work()
# Out:
# sylvia is busy now

# %%
help(y)
# Out:
# Help on person in module __main__ object:
#
# class person(builtins.object)
#  |  person(name, age, gender, occupation)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, name, age, gender, occupation)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  eat(self)
#  |
#  |  talk(self)
#  |
#  |  walk(self)
#  |      #Methods()
#  |
#  |  work(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
list_1=[2,3,4,5]
help(list_1)
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, index, /)
#  |      Return self[index].
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %% [markdown]
# #Example

# %% [markdown]
# Create a Python class called Student with the following requirements:
#
# 1- The class should have a constructor (__init__) that takes the student's name as input and initializes an empty list to store marks.
#
# 2- Implement a method called add_marks(mark) that:
# Adds a mark to the student's marks list Validates that the mark is between 0 and 100 Prints an error message if the mark is invalid
#
# 3-Implement a method called calculate_sum() that:
# Returns the sum of all marks
# Returns 0 if no marks are available
#
# 4-Implement a method called show_details() that:
# Displays the student's name
# Displays all marks
# Displays the sum marks

# %%
class student:
  def __init__(self,name):
    self.name=name
    self.marks=[]


  def add_marks(self,m):
    if m >0 and m <=100:
       self.marks.append(m)
       print("mark is added")
    else:
      print("invalid Mark")

  def calculate_sum(self):
    if len(self.marks)==0:
      return 0
    else:
       print(sum(self.marks))

  def show_details(self):
      print(f"your name is :: {self.name} ")
      print(f"your marks are :: {self.marks} ")
      print(f"your total marks is :: {sum(self.marks)} ")

# %%
s=student('Yasmin')

# %%
s.add_marks(90)
s.add_marks(80)
s.add_marks(120)
s.add_marks(50)
# Out:
# mark is added
# mark is added
# invalid Mark
# mark is added

# %%
s.calculate_sum()
# Out:
# 300

# %%
s.show_details()
# Out:
# your name is :: Yasmin
# your marks are :: [100, 100, 100]
# your total marks is :: 300

# %% [markdown]
# create a calculator class that contain constructor __init__ that take 2 numbers , create method for addition and another one for multiplication

# %%
class calculator:
  def __init__(self,num1,num2):
    self.num1=num1
    self.num2=num2

  def add(self):
    print(self.num1+self.num2)

  def mul(self):
    print(self.num1*self.num2)

# %%
c1=calculator(10,20)

c1.add()

c1.mul()
# Out:
# 30
# 200

# %% [markdown]
# #Inheritance

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class animal:
  def __init__(self,name):
    self.name=name

  def eat(self):
    print(self.name," is eating")

  def sleep(self):
    print(self.name," is sleeping")

# %%
class dog(animal):
  def speak(self):
    print(self.name," braking")

# %%
class Animal:
    def __init__(self, name):
        self.name = name

    def eat(self):
        print(f"{self.name} is eating")

    def sleep(self):
        print(f"{self.name} is sleeping")

# %%
class Dog(Animal):
    def bark(self):
        print(f"{self.name} is barking")

# %%
class Cat(Animal):
    def speak(self):
        print(f"{self.name} is MEww")

# %%
x=Dog("copito")
x.eat()
x.bark()
# Out:
# copito is eating
# copito is barking

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Create a parent class vehicle with its constructor taht take the type/name of this vehicle , create method (start) that say this vehicle is starting , another one (stop) that say this vehicle is stopped
# then create car class that inherit from vehicle class and create method called (drive) and print any message in this method

# %%
class Vehicle:
    def __init__(self, type):
        self.type = type

    def start(self):
        print(f"{self.type} is starting")

    def stop(self):
        print(f"{self.type} is stopping")

# %%
class Car(Vehicle):
    def drive(self):
        print(f"{self.type} car is driving ")

# %%
c1=Car('toyota')
c1.start()
c1.stop()
c1.drive()
# Out:
# toyota is starting
# toyota is stopping
# toyota car is driving

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #super constructor

# %% [markdown]
# #call the constructor of parent class

# %%
class Animal:
    def __init__(self, name):
        self.name = name

# %%
class Dog(Animal):
    def __init__(self, name, type):
        super().__init__(name)
        self.type = type

# %%
d=Dog('copito','coker')

# %% [markdown]
# Create a vehicle class (parent) with attributes brand then create class car with additional attribut is model

# %%
class vehicle:
  def __init__(self,brand):
    self.brand=brand

# %%
class car(vehicle):
  def __init__(self,brand,model):
    super().__init__(brand)
    self.model=model

# %%
c = car("Toyota", "2010")

# %% [markdown]
# #polymorphism

# %% [markdown]
# same Method excute in different ways

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def role(self):
        print("I am a student")

    def study(self):
      print("I'm studying now")

# %%
class UniversityStudent(Student):
    def role(self):
        print(f"{self.name} : I am a university student")

# %%
class SchoolStudent(Student):
    def role(self):
        print(f"{self.name} I am a school student")

# %%
student_1=UniversityStudent('ahmed',21)
student_2=SchoolStudent('yasmin',16)
student_1.role()
student_2.role()
# Out:
# ahmed : I am a university student
# yasmin I am a school student

# %% [markdown]
# #Abstract base Class = Interface

# %% [markdown]
# Contract : yagber kol class 3la some of  methods

# %%
from abc import ABC , abstractmethod

# %% [markdown]
# #Payment system
#  has pay() method

# %%
class payment_Method(ABC):
    @abstractmethod
    def pay(self,amount):
        pass

# %% [markdown]
# 💳 Credit Card

# %%
class CreditCard(payment_Method):
    def pay(self, amount):
        print(f"Paid {amount} using Credit Card")

# %% [markdown]
# 💰 Cash

# %%
class Cash(payment_Method):
    def pay(self, amount):
        print(f"Paid {amount} in Cash")

# %%
x=CreditCard()
x.pay(200)
# Out:
# Paid 200 using Credit Card

# %%
y=Cash()
y.pay(200)
# Out:
# Paid 200 in Cash

# %%
from abc import ABC, abstractmethod

class Animal(ABC):

    def sleep(self):
        print("Sleeping...")

    @abstractmethod
    def make_sound(self):
        pass


class dog(Animal):

  def make_sound(self):
     print("jmfjrmdgrtjmgkmf")

# %%
x=dog()

# %%
x.make_sound()
# Out:
# jmfjrmdgrtjmgkmf

# %%
x.sleep()
# Out:
# Sleeping...

# %% [markdown]
# ##Write a Python program to create a class representing a Circle. Include methods to calculate its area .

# %%
class Circle:
    def __init__(self, radius):
        self.radius = radius

    def calculate_circle_area(self):
        return 3.18 * self.radius**2


#------------------------------------------------------------------------------
radius = float(input("Input the radius of the circle: "))

circle = Circle(radius)

area = circle.calculate_circle_area()


print("Area of the circle:", area)
# Out:
# Input the radius of the circle: 2
# Area of the circle: 12.72

# %% [markdown]
# ##Write a Python program to create a person class. Include attributes like name, country and date of birth. Implement a method to determine the person's age.

# %%
from datetime import date

class Person:
    def __init__(self, name, country, date_of_birth):
        self.name = name
        self.country = country
        self.date_of_birth = date_of_birth

    def calculate_age(self):
        today = date.today()
        age = today.year - self.date_of_birth.year
        return age

#-----------------------------------------------------------------------------------
person1 = Person("soha", "Egypt", date(1995, 7, 12))
person2 = Person("jana", "Canada", date(2008, 10, 20))
person3 = Person("Mohamed", "USA", date(2000, 1, 1))

#--------------------------------------------------------------------------------------
print("Person 1:")
print("Name:", person1.name)
print("Country:", person1.country)
print("Date of Birth:", person1.date_of_birth)
print("Age:", person1.calculate_age())

#--------------------------------------------------------------------------------------

print("\nPerson 2:")
print("Name:", person2.name)
print("Country:", person2.country)
print("Date of Birth:" , person2.date_of_birth)
print("Age:", person2.calculate_age())

#--------------------------------------------------------------------------------------

print("\nPerson 3:")
print("Name:", person3.name)
print("Country:", person3.country)
print("Date of Birth:", person3.date_of_birth)
print("Age:", person3.calculate_age())
# Out:
# Person 1:
# Name: soha
# Country: Egypt
# Date of Birth: 1995-07-12
# Age: 31
#
# Person 2:
# Name: jana
# Country: Canada
# Date of Birth: 2008-10-20
# Age: 18
#
# Person 3:
# Name: Mohamed
# Country: USA
# Date of Birth: 2000-01-01
# Age: 26

# %% [markdown]
# ##3. Calculator Class for Basic Arithmetic Operations
#
# Write a Python program to create a calculator class. Include methods for basic arithmetic operations.

# %%
class Calculator:
    def add(self, x, y):
        return x + y

    def subtract(self, x, y):
        return x - y

    def multiply(self, x, y):
        return x * y

    def divide(self, x, y):
        if y != 0:
            return x / y
        else:
            return ("Cannot divide by zero.")

#------------------------------------------------------------
calculator = Calculator()


result = calculator.add(7, 5)
print("7 + 5 =", result)


result = calculator.subtract(34, 21)
print("34 - 21 =", result)


result = calculator.multiply(54, 2)
print("54 * 2 =", result)


result = calculator.divide(144, 2)
print("144 / 2 =", result)


result = calculator.divide(45, 0)
print("45 / 0 =", result)
# Out:
# 7 + 5 = 12
# 34 - 21 = 13
# 54 * 2 = 108
# 144 / 2 = 72.0
# 45 / 0 = Cannot divide by zero.

# %% [markdown]
# ##Write a Python program to create a class that represents a shape. Include methods to calculate its area and perimeter. Implement subclasses for different shapes like circle, triangle, and square.

# %%
class Shape:
    def calculate_area(self):
        pass

    def calculate_perimeter(self):
        pass

#---------------------------------------------------------------------------------
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.18 * self.radius**2

    def calculate_perimeter(self):
        return 2 * 3.18 * self.radius

#---------------------------------------------------------------------------------

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width


    def calculate_area(self):
        return self.length * self.width

    def calculate_perimeter(self):
        return 2 * (self.length + self.width)

#---------------------------------------------------------------------------------


class Triangle(Shape):
    def __init__(self, base, height, side1, side2, side3):
        self.base = base
        self.height = height
        self.side1 = side1
        self.side2 = side2
        self.side3 = side3

    def calculate_area(self):
        return 0.5 * self.base * self.height

    def calculate_perimeter(self):
        return self.side1 + self.side2 + self.side3

#---------------------------------------------------------------------------------


r = 7
circle = Circle(r)
circle_area = circle.calculate_area()
circle_perimeter = circle.calculate_perimeter()


print("Radius of the circle:", r)
print("Circle Area:", circle_area)
print("Circle Perimeter:", circle_perimeter)

#---------------------------------------------------------------------------------

l = 5
w = 7
rectangle = Rectangle(l, w)
rectangle_area = rectangle.calculate_area()
rectangle_perimeter = rectangle.calculate_perimeter()


print("\nRectangle: Length =", l, " Width =", w)
print("Rectangle Area:", rectangle_area)
print("Rectangle Perimeter:", rectangle_perimeter)
#---------------------------------------------------------------------------------


base = 5
height = 4
s1 = 4
s2 = 3
s3 = 5

print("\nTriangle: Base =", base, " Height =", height, " side1 =", s1, " side2 =", s2, " side3 =", s3)
triangle = Triangle(base, height, s1, s2, s3)
triangle_area = triangle.calculate_area()
triangle_perimeter = triangle.calculate_perimeter()
print("Triangle Area:", triangle_area)
print("Triangle Perimeter:", triangle_perimeter)

#---------------------------------------------------------------------------------
# Out:
# Radius of the circle: 7
# Circle Area: 155.82000000000002
# Circle Perimeter: 44.52
#
# Rectangle: Length = 5  Width = 7
# Rectangle Area: 35
# Rectangle Perimeter: 24
#
# Triangle: Base = 5  Height = 4  side1 = 4  side2 = 3  side3 = 5
# Triangle Area: 10.0
# Triangle Perimeter: 12
