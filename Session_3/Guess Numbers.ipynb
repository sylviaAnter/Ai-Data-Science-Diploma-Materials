# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import random

print("Welcome to the Number Guessing Game!")

random_number = random.randint(1, 10)
ctr = 0

while True:
    guess = int(input("Guess a number between 1 and 100: "))
    ctr += 1

    if guess == random_number:
        print(f"Correct! You guessed the number in {ctr} times.")
        break

    elif guess < random_number:
        print("Higher.")

    else:
        print("Lower.")
# Out:
# Welcome to the Number Guessing Game!
# Guess a number between 1 and 100: 2
# Higher.
# Guess a number between 1 and 100: 5
# Higher.
# Guess a number between 1 and 100: 8
# Higher.
# Guess a number between 1 and 100: 9
# Correct! You guessed the number in 4 times.
