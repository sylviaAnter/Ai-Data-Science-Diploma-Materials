# %% [markdown]
# #Revision

# %%
#create list
x_list=[1,2,3]
#create dic
x_dic={'key': 'value'}
#create tuple
x_tuple=(1,2,3)
#create set
x_set={1,2,3}

# %%
#get element from list
x_list[0]
#get element dic
x_dic['key']
# Out:
# 'value'

# %% [markdown]
# ##Create 2D Array , list

# %%
x_list=[[1,2],[1,2]]
x_list
# Out:
# [[1, 2], [1, 2]]

# %%
#acess to the second number in the second array
x_list[1][1]
# Out:
# 2

# %%
#replace the even number in the second array with -
for i in range(2):
  if i == 1:
    for j in range(2):
      if j == 1:
        if x_list[i][j] % 2 ==0:
           x_list[i][j]='-'
x_list
# Out:
# [[1, 2], [1, '-']]

# %% [markdown]
#  Generate 3D Array
#
# Write a Python program to generate a 3D  array whose each element is #.

# %%
arr=[[[1,2],[3,4]],[[1,2],[3,4]]]

print(arr)
# Out:
# [[[1, 2], [3, 4]], [[1, 2], [3, 4]]]

# %% [markdown]
# from arr select the second number 4 in the third list

# %%
arr[1][1][1]
# Out:
# 4

# %% [markdown]
# Remove Even Numbers from third List

# %%
arr=[[[1,2],[3,4]],[[1,2],[3,4]]]

for i in range(2):
  if i == 1:
    for j in range(2):
      if j == 1:
        for k in range(2):
          if arr[i][j][k] % 2 ==0:
             arr[i][j][k]='-'
print(arr)
# Out:
# [[[1, 2], [3, 4]], [[1, 2], [3, '-']]]

# %% [markdown]
# [[[1, 2], [3, 4]], [[1, 2], [3, '-']]]

# %%
#get 4 , last 3
arr[0][1][1]
# Out:
# 4

# %%
arr[1][1][0]
# Out:
# 3

# %% [markdown]
#  Create List of Dictionaries

# %%
list_of_dic = [
    {'k1': 'v1', 'k2': 'v2'},
    {'k3': 'v3', 'k4': 'v4'}
]
list_of_dic[1]['k4']
# Out:
# 'v4'

# %%
list_of_dic = [
    {'k1': 'v1', 'k2': ['v10','v20','v30']},
    {'k1_2': 'v1_2', 'key2_2': 'value2_2'}
]
list_of_dic[0]['k2']
# Out:
# ['v10', 'v20', 'v30']

# %%
list_of_dic = [
    {'k1': 'v1', 'k2': ['v10','v20','v30']},
    {'k1_2': 'v1_2', 'key2_2': 'value2_2'}
]
list_of_dic[0]['k2'][2]
# Out:
# 'v30'

# %%
list_of_dic = [
    {'k1': 'v1', 'k2': ['v10','v20','v30']},
    {'k1_2': ['v100','v200','v300'], 'key2_2': 'value2_2'}
]
list_of_dic[1]['k1_2'][1]
# Out:
# 'v200'

# %%
d = {'k1':[1,2,{'k2':['practice',{'hard':[1,2,['hello']]}]}]}
#get letter 'O' in hello
d['k1'][2]['k2'][1]['hard'][2][0][4]
# Out:
# 'o'

# %% [markdown]
# You are given an integer x
# . You need to find the smallest non-negative integer y
#  such that the numbers x
#  and y
#  share at least one common digit. In other words, there must exist a decimal digit d
#  that appears in both the representation of the number x
#  and the number y
# .
#
# Input
# The first line contains an integer t
#  (1≤t≤1000
# ) — the number of test cases.
#
# The first line of each test case contains one integer x
#  (1≤x≤1000
# ).
#
# Output
# For each test case, output one integer y
#  — the minimum non-negative number that satisfies the condition.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n=int(input())
x=[]
for i in range(0,n):
  y=input()
  x.append(y)
#-------------------------
for item in x:
  d=[]
  for letter in item:
    d.append(int(letter))
  print(min(d))
# Out:
# 3
# 10
# 12
# 15
# 0
# 1
# 1
